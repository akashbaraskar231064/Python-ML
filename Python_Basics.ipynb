# %% [markdown]
# <a href="https://colab.research.google.com/github/akashbaraskar231064/Python-ML/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=9
print(n, 'binary', format(n, 'b'))
print(n, '* 2 =' , n<<1, format(n<<1, 'b'))
print(n, '/ 2 =' , n>>1, format(n>>1, 'b'))
# Out:
# 9 binary 1001
# 9 * 2 = 18 10010
# 9 / 2 = 4 100

# %%
x = True
y = False
print('x and y', x and y)
print('x or y', x or y)
print('not x is', not x)
# Out:
# x and y False
# x or y True
# not x is False

# %%
x = True
y = False
print('x and y', x & y)
print('x or y', x | y)
print('not x is', not x)
# Out:
# x and y False
# x or y True
# not x is False

# %%
x = 12
y=4
print(x & y)
print(x | y)
print(x ^ y)
# Out:
# 4
# 12
# 8

# %%
x = 'Hello World'
print('H' in x)
print('h' not in x)
# Out:
# True
# True

# %%
import cmath
a=complex(20+5j)
b=complex(5+3j)
print('a+b', a+b)
print('a-b', a-b)
print('a*b', a*b)
print('a/b', a/b)
# Out:
# a+b (25+8j)
# a-b (15+2j)
# a*b (85+85j)
# a/b (3.3823529411764706-1.0294117647058825j)

# %%
a=complex(20+5j)
b=complex(5+3j)
print('a+b', a+b)
print('a-b', a-b)
print('a*b', a*b)
print('a/b', a/b)
# Out:
# a+b (25+8j)
# a-b (15+2j)
# a*b (85+85j)
# a/b (3.3823529411764706-1.0294117647058825j)

# %%
a=int(input('get the value a: '))
b=int(input('get the value b: '))
c=int(input('get the value c: '))
s=(a+b+c)/2
print(s)
area=cmath.sqrt(s*(s-a)*(s-b)*(s-c))
print(area)
# Out:
# get the value a: 2
# get the value b: 3
# get the value c: 4
# 4.5
# (2.9047375096555625+0j)

# %%
a= input('enter char: ')
a = a.lower()
if(a == 'a' or a=='e' or a=='i' or a=='o' or a=='u'):
  print('vowel')
else:
  print('consonent')
# Out:
# enter char: d
# consonent

# %%
numbers = []

print("Enter numbers one by one. Type 'done' to finish.")

while True:
    user_input = input("Enter a number: ")

    # Check if the user wants to stop
    if user_input.lower() == 'done':
        break

    try:
        # Convert input to a float to handle decimals
        num = float(user_input)
        numbers.append(num)
    except ValueError:
        print("Invalid input. Please enter a number or 'done'.")

# Check if the list isn't empty before finding max
if numbers:
    max_val = max(numbers)
    print(f"The maximum number entered is: {max_val}")
else:
    print("No numbers were entered.")
# Out:
# Enter numbers one by one. Type 'done' to finish.
# Enter a number: 5
# Enter a number: 8
# Enter a number: 9
# Enter a number: 7
# Enter a number: 8
# Enter a number: 45
# Enter a number: done
# The maximum number entered is: 45.0

# %%
class Car:
  def __init__(self, brand, model, year):
    self.brand = brand
    self.model = model
    self.year = year

  def display_info(self):
    print(f"Car: {self.brand} {self.model} {self.year}")

car1 = Car("Toyota", "Corolla", 2022)
car2 = Car("Tesla", "Model S", 2023)

car1.display_info()
car2.display_info()
# Out:
# Car: Toyota Corolla 2022
# Car: Tesla Model S 2023

# %%
class Employee:
  def __init__(self, Name, Id,  Salary):
    self.Name = Name
    self.Id = Id
    self.Salary = Salary

  def display_info(self):
    print(f'Employee: {self.Name} (self.Id) {self.Salary}')

emp1 = Employee("Avi", "a1", "55000")
emp2 = Employee("Dipesh", "d1", "50000")

emp1.display_info()
emp2.display_info()
# Out:
# Employee: Avi (self.Id) 55000
# Employee: Dipesh (self.Id) 50000

# %%
class Student:
  def __init__(self, Name, Marks,  Course):
    self.Name = Name
    self.Marks = Marks
    self.Course = Course

  def display_info(self):
    print(f'Student: {self.Name} {self.Marks} {self.Course}')

stu1 = Employee("Avi", "55", "B.tech")
stu2 = Employee("Dipesh", "45", "B.tech")

stu1.display_info()
stu2.display_info()
# Out:
# Employee: Avi (self.Id) B.tech
# Employee: Dipesh (self.Id) B.tech
